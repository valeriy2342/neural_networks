# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.layers import SimpleRNN, LSTM, GRU
from keras.models import Sequential


# построчное чтение из примера с текстом
with open('alice_in_wonderland.txt', 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("ascii", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)


# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10 символов
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 128, 128
NUM_ITERATIONS = 25 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100


# Create a super simple recurrent neural network. There is one recurrent
# layer that produces an embedding of size HIDDEN_SIZE from the one-hot
# encoded input layer. This is followed by a Dense fully-connected layer
# across the set of possible next characters, which is converted to a
# probability score via a standard softmax activation with a multi-class
# cross-entropy loss function linking the prediction to the one-hot
# encoding character label.

'''
Создание очень простой рекуррентной нейронной сети. В ней будет один реккурентный закодированный входной слой. За ним последует полносвязный слой связанный с набором возможных следующих символов, которые конвертированы в вероятностные результаты через стандартную softmax активацию с multi-class cross-encoding loss функцию ссылающуются на предсказание one-hot encoding лейбл символа
'''

model = Sequential()
model.add(
    GRU(  # вы можете изменить эту часть на LSTM или SimpleRNN, чтобы попробовать альтернативы
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")


# выполнение серий тренировочных и демонстрационных итераций
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# <ipython-input-23-7a40aa7e98cf>:39: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
# <ipython-input-23-7a40aa7e98cf>:40: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
# ==================================================
# Итерация #: 0
# 1241/1241 [==============================] - 40s 30ms/step - loss: 2.3527
# Генерация из посева: it,) he di
# it,) he ding the wand the wand the wand the wand the wand the wand the wand the wand the wand the wand the wan==================================================
# Итерация #: 1
# 1241/1241 [==============================] - 38s 30ms/step - loss: 1.9736
# Генерация из посева:  accountin
#  accounting the grown the grown the grown the grown the grown the grown the grown the grown the grown the grow==================================================
# Итерация #: 2
# 1241/1241 [==============================] - 37s 30ms/step - loss: 1.8116
# Генерация из посева: ople who a
# ople who a dory and the was a little said the was a little said the was a little said the was a little said th==================================================
# Итерация #: 3
# 1241/1241 [==============================] - 37s 29ms/step - loss: 1.6967
# Генерация из посева: before see
# before see the morst to see the morst to see the morst to see the morst to see the morst to see the morst to s==================================================
# Итерация #: 4
# 1241/1241 [==============================] - 41s 33ms/step - loss: 1.6084
# Генерация из посева: d the rose
# d the rose the could the could the could the could the could the could the could the could the could the could==================================================
# Итерация #: 5
# 1241/1241 [==============================] - 37s 29ms/step - loss: 1.5387
# Генерация из посева: ever, thou
# ever, thought the mouse she was the mouse she was the mouse she was the mouse she was the mouse she was the mo==================================================
# Итерация #: 6
# 1241/1241 [==============================] - 36s 29ms/step - loss: 1.4816
# Генерация из посева: nowledge,
# nowledge, and the dormouse the looked and the dormouse the looked and the dormouse the looked and the dormouse==================================================
# Итерация #: 7
# 1241/1241 [==============================] - 36s 29ms/step - loss: 1.4331
# Генерация из посева: ut he coul
# ut he could not a little she was not a mouse in a look of the things and alice was not a mouse in a look of th==================================================
# Итерация #: 8
# 1241/1241 [==============================] - 36s 29ms/step - loss: 1.3934
# Генерация из посева:  trembling
#  trembling for the dormouse in the dormouse in the dormouse in the dormouse in the dormouse in the dormouse in==================================================
# Итерация #: 9
# 1241/1241 [==============================] - 36s 29ms/step - loss: 1.3582
# Генерация из посева: on her eye
# on her eyes the little been a little sightenting the mouse the little been a little sightenting the mouse the ==================================================
# Итерация #: 10
# 1241/1241 [==============================] - 36s 29ms/step - loss: 1.3277
# Генерация из посева: res in won
# res in wonder at the work the mouse the mouse the mouse the mouse the mouse the mouse the mouse the mouse the ==================================================
# Итерация #: 11
# 1241/1241 [==============================] - 37s 29ms/step - loss: 1.3003
# Генерация из посева: uch a dear
# uch a dear! said the dormouse she was to do something of the work or a more that she was a little before she w==================================================
# Итерация #: 12
# 1241/1241 [==============================] - 37s 30ms/step - loss: 1.2753
# Генерация из посева:  being pin
#  being pince, who was the work out of the works in a long and said to herself and she was all the work out of ==================================================
# Итерация #: 13
# 1241/1241 [==============================] - 36s 29ms/step - loss: 1.2534
# Генерация из посева: r, too far
# r, too farther the execution of the words and the same the mouse the words and the same the mouse the words an==================================================
# Итерация #: 14
# 1241/1241 [==============================] - 37s 30ms/step - loss: 1.2333
# Генерация из посева: nd shook i
# nd shook it was a little shimply and a little shimply and a little shimply and a little shimply and a little s==================================================
# Итерация #: 15
# 1241/1241 [==============================] - 36s 29ms/step - loss: 1.2143
# Генерация из посева: ng against
# ng against the project gutenberg-tm electronic works in a long remark and distributed and distributed and dist==================================================
# Итерация #: 16
# 1241/1241 [==============================] - 37s 30ms/step - loss: 1.1975
# Генерация из посева: at dismay,
# at dismay, and the mock turtle with the gryphon said the dormouse, and she was going to herself, and she was g==================================================
# Итерация #: 17
# 1241/1241 [==============================] - 39s 31ms/step - loss: 1.1807
# Генерация из посева:  these cak
#  these cakes and the mock turtle was the reason of the mock turtle was the reason of the mock turtle was the r==================================================
# Итерация #: 18
# 1241/1241 [==============================] - 37s 30ms/step - loss: 1.1659
# Генерация из посева: thing you
# thing you was the caterpillar. well, it was a little begon, said the caterpillar. well, it was a little begon,==================================================
# Итерация #: 19
# 1241/1241 [==============================] - 37s 29ms/step - loss: 1.1508
# Генерация из посева: as waving
# as waving she was not a little begon, said the dock turtle so much of the shole the reason of the soon at the ==================================================
# Итерация #: 20
# 1241/1241 [==============================] - 37s 30ms/step - loss: 1.1377
# Генерация из посева: lice, were
# lice, were all the same thing a little beginning to herself, and she was going on the same thing a little begi==================================================
# Итерация #: 21
# 1241/1241 [==============================] - 37s 30ms/step - loss: 1.1245
# Генерация из посева:  declared
#  declared of the court, and the party was the caterpillar. alice was an once of the court, and the party was t==================================================
# Итерация #: 22
# 1241/1241 [==============================] - 36s 29ms/step - loss: 1.1124
# Генерация из посева: s about it
# s about it, said the dormouse she was an old not confusing at the thing that the door as she could not state d==================================================
# Итерация #: 23
# 1241/1241 [==============================] - 37s 29ms/step - loss: 1.1003
# Генерация из посева:  was begin
#  was beginning to herself to the patter of the triel to be sure, said the mock turtle sent the things it was a==================================================
# Итерация #: 24
# 1241/1241 [==============================] - 37s 30ms/step - loss: 1.0887
# Генерация из посева: t up and l
# t up and looked at the mouse to see it was a little golden key and the sort of the words and the sort of the w
